# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahsin-20/Python-Libraries/blob/main/Pandas/Pandas(Series)/Pandas(Series).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# https://pandas.pydata.org/about/index.html

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
#String type series (String is called object in Pandas)
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
#Integers
runs = [13,24,56,78,100]

runs_ser=pd.Series(runs)
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
#Custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
#Setting a name
marks = pd.Series(marks,index=subjects,name='Tahsin er marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Tahsin er marks, dtype: int64

# %% [markdown]
# ### Series from dictionary

# %%
#Series from dic
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='Tahsin er marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Tahsin er marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
#size
marks_series.size
# Out:
# 4

# %%
#dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#name
marks_series.name
# Out:
# 'Tahsin er marks'

# %%
#Returns boolean value if unique values or not
marks_series.is_unique

pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
#Gives indices value
marks_series.index
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#Gives value
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ### Series using read_csv

# %%
#Reads csv files to series
subs = pd.read_csv('/content/subs.csv').squeeze('columns')
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#With 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series methods

# %%
#Head and Tail (Shows preview not copying)
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
#Shows top 3 data
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
#Shows last 10 data
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
#Shows random (n) data
movies.sample(5)
# Out:
# movie
# Aisa Yeh Jahaan        Yashpal Sharma
# Loveshhuda             Girish Taurani
# Gulaal (film)           Kay Kay Menon
# Pyare Mohan              Fardeen Khan
# Anamika (2008 film)        Dino Morea
# Name: lead, dtype: object

# %%
#Value_counts -> movies (Frequency count)
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
#Sort_values -> inplace
vk.sort_values(ascending=False)
vk.sort_values(ascending=False).head(1).values[0]
vk = vk.sort_values() #Sorts values inplace
vk
# Out:
# match_no
# 8        0
# 87       0
# 93       0
# 91       0
# 206      0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
#Sort_index -> inplace -> movies (Changes original series in alphabetical order)
movies.sort_index(ascending=False,inplace=True)

# %% [markdown]
# ### Series Maths Methods

# %%
#Count (Only no missing values)
vk.count()
# Out:
# np.int64(215)

# %%
#Sum -> product
subs.sum()
subs.product()
# Out:
# np.int64(0)

# %%
#mean -> median -> mode -> std -> var
print(subs.mean())
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 135.64383561643837
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.67502303725269
# 688.0024777222342

# %%
#min/max
subs.max()
subs.min()
# Out:
# 33

# %%
#Provides summary about the data
subs.describe()
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
#Integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
#Negative indexing (Only works when indices are string not otherwise)
x[-1]
movies[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2763/2489608868.py in <cell line: 0>()
#       1 #Negative indexing (Only works when indices are string not otherwise)
# ----> 2 x[-1]
#       3 movies[-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
# ...

# %%
#Slicing
vk[5:16]
# Out:
# match_no
# 207    0
# 135    0
# 130    0
# 211    0
# 106    1
# 204    1
# 113    1
# 77     1
# 1      1
# 5      1
# 75     1
# Name: runs, dtype: int64

# %%
#Negative slicing
vk[-5:]
# Out:
# match_no
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, dtype: int64

# %%
movies[::2]
# Out:
# movie
# Zor Lagaa Ke...Haiya!         Meghan Jadhav
# Zindagi Tere Naam        Mithun Chakraborty
# Zindagi 50-50                   Veena Malik
# Zinda (film)                    Sanjay Dutt
# Zid (2014 film)              Mannara Chopra
#                                 ...
# 3 Storeys                       Aisha Ahmed
# 3 Deewarein                Naseeruddin Shah
# 22 Yards                        Barun Sobti
# 1971 (2007 film)             Manoj Bajpayee
# 1920: London                  Sharman Joshi
# Name: lead, Length: 750, dtype: object

# %%
#Fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
#Indexing with labels -> fancy indexing
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ### Editing Series

# %%
#Using indexing
marks_series[1] = 100
marks_series
# Out:
# /tmp/ipykernel_2763/2544619804.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: Tahsin er marks, dtype: int64

# %%
#What if an index does not exist
marks_series['evs'] = 100
marks_series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# evs        100
# Name: Tahsin er marks, dtype: int64

# %%
#Slicing
runs_ser[2:4] = [100,100]
runs_ser
# Out:
# 0     13
# 1     24
# 2    100
# 3    100
# 4    100
# dtype: int64

# %%
#Fancy indexing
runs_ser[[0,3,4]] = [0,0,0]
runs_ser
# Out:
# 0      0
# 1     24
# 2    100
# 3      0
# 4      0
# dtype: int64

# %%
#Using index label
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies
# Out:
# movie
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Zokkomon                       Darsheel Safary
# Zindagi Tere Naam           Mithun Chakraborty
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi 50-50                      Veena Malik
#                                    ...
# 2 States (2014 film)                Alia Bhatt
# 1971 (2007 film)                Manoj Bajpayee
# 1920: The Evil Returns             Vicky Ahuja
# 1920: London                     Sharman Joshi
# 1920 (film)                   Rajniesh Duggall
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series with Python Functionalities

# %%
#Length of row/Type of datat/Dir/Sorted in a list/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
#Type conversion
list(marks_series)
# Out:
# [67, 100, 89, 100, 100]

# %%
dict(marks_series)

# %%
#Membership operator (Only searches in indices in default)

'2 States (2014 film)' in movies

# %%
'Alia Bhatt' in movies.values

# %%
#Looping (Runs on values)
for i in movies.index:
  print(i)

# %%
#Arithmetic Operators(Broadcasting)
#Works on all arithmatic operators
100 - marks_series

# %%
#Relational Operators

vk >= 50

# %% [markdown]
# ### Boolean Indexing on Series

# %%
#Find no of 50's and 100's scored by kohli
vk[vk >= 50]

# %%
#Find number of ducks
vk[vk == 0].size

# %%
#Count number of day when I had more than 200 subs a day
subs[subs > 200].size

# %%
#Find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()

# %%
movies.value_counts().head(20).plot(kind='bar')

# %%
movies.value_counts().head(20).plot(kind='pie')

# %% [markdown]
# ### Some Important Series Methods

# %%
#Changes datatype (Reduces memory)
import sys
sys.getsizeof(vk)

# %%
sys.getsizeof(vk.astype('int16'))

# %%
#Find out data between a range (Both numbers included)
vk[vk.between(51,99)]
# Out:
# match_no
# 197    51
# 71     51
# 103    51
# 122    52
# 198    53
# 131    54
# 129    54
# 137    55
# 44     56
# 85     56
# 144    57
# 57     57
# 80     57
# 34     58
# 209    58
# 141    58
# 73     58
# 104    62
# 132    62
# 134    64
# 74     65
# 45     67
# 162    67
# 97     67
# 148    68
# 52     70
# 152    70
# 41     71
# 175    72
# 188    72
# 68     73
# 213    73
# 99     73
# 127    75
# 116    75
# 117    79
# 119    80
# 110    82
# 160    84
# 178    90
# 145    92
# 81     93
# 82     99
# Name: runs, dtype: int64

# %%
#Clips the numbers in two number
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
temp = pd.Series([1,1,2,2,3,3,4,4])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
#Drops duplicate values
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 4    3
# 6    4
# dtype: int64

# %%
#Finds out the number of duplicated values
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
tempo= pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
tempo
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
#Returns the size including the missing values
tempo.size
# Out:
# 10

# %%
#Returns the size without the missing values
tempo.count()
# Out:
# np.int64(7)

# %%
#Finds out number of null values
tempo.isnull().sum()
# Out:
# np.int64(3)

# %%
#Drops missing values
temp.dropna()

# %%
#Fills missing value by a targetted number
temp.fillna(temp.mean())
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
#Finds out the indices of targetted number
vk[vk.isin([49,99])]
# Out:
# match_no
# 86    49
# 82    99
# Name: runs, dtype: int64

# %%
#Applies a specific function with specific logics
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Zor Lagaa Ke...Haiya!         MEGHAN
# Zokkomon                    DARSHEEL
# Zindagi Tere Naam             MITHUN
# Zindagi Na Milegi Dobara     HRITHIK
# Zindagi 50-50                  VEENA
#                               ...
# 2 States (2014 film)            ALIA
# 1971 (2007 film)               MANOJ
# 1920: The Evil Returns         VICKY
# 1920: London                 SHARMAN
# 1920 (film)                 RAJNIESH
# Name: lead, Length: 1500, dtype: object

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
#Creates a copy of data
new = vk.head().copy()
new[1] = 100

# %%
print(new)
print(vk)
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
